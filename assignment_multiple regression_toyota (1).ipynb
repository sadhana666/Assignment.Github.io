# %%
import pandas as pd
import numpy as np
import pandas_profiling as pp
import sweetviz as sv
import matplotlib.pyplot as plt

# %%
toyota=pd.read_excel("E:\\Desktop\kaggle.xlsx")# read excel sheet

# %%
toyota
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     16450         20  22588   97  1400      5      5             85    1110
# 1      7950         75  57144  110  1600      5      5             85    1070
# 2     10950         59  79660   86  1300      5      5             85    1065
# 3      8950         65  60000   86  1300      3      5             69    1015
# 4      9950         55  44537   97  1400      3      5             69    1025
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1287   8950         61  81170  110  1600      4      5             69    1040
# 1288   6750         69  60050  110  1600      3      5             69    1050
# 1289   7400         75  74096  110  1600      3      5             69    1050
# 1290  11450         50  50400  110  1600      5      5             85    1080
# 1291   8500         74  66718  110  1600      3      5             69    1050
#
# [1292 rows x 9 columns]

# %%
toyota.to_csv("toyota.csv") #convert excel sheet into csv file

# %%
toyota1=pd.read_csv('toyota.csv')# read csv file

# %%
toyota1
# Out:
#       Unnamed: 0  Price  Age_08_04     KM   HP    cc  Doors  Gears  \
# 0              0  16450         20  22588   97  1400      5      5
# 1              1   7950         75  57144  110  1600      5      5
# 2              2  10950         59  79660   86  1300      5      5
# 3              3   8950         65  60000   86  1300      3      5
# 4              4   9950         55  44537   97  1400      3      5
# ...          ...    ...        ...    ...  ...   ...    ...    ...
# 1287        1287   8950         61  81170  110  1600      4      5
# 1288        1288   6750         69  60050  110  1600      3      5
# 1289        1289   7400         75  74096  110  1600      3      5
# 1290        1290  11450         50  50400  110  1600      5      5
# 1291        1291   8500         74  66718  110  1600      3      5
#
#       Quarterly_Tax  Weight
# 0                85    1110
# 1                85    1070
# 2                85    1065
# 3                69    1015
# ...

# %%
toyota1.shape # check how many rows and columns
# Out:
# (1292, 10)

# %%
toyota1.dtypes# check the dtypes of variable
# Out:
# Unnamed: 0       int64
# Price            int64
# Age_08_04        int64
# KM               int64
# HP               int64
# cc               int64
# Doors            int64
# Gears            int64
# Quarterly_Tax    int64
# Weight           int64
# dtype: object

# %% [markdown]
# # Rename the columns

# %%
toyota = toyota1.rename({'Quarterly_Tax': 'QuarterlyTax','Age_08_04':'Age0804'}, axis=1)

# %%
toyota
# Out:
#       Unnamed: 0  Price  Age0804     KM   HP    cc  Doors  Gears  \
# 0              0  16450       20  22588   97  1400      5      5
# 1              1   7950       75  57144  110  1600      5      5
# 2              2  10950       59  79660   86  1300      5      5
# 3              3   8950       65  60000   86  1300      3      5
# 4              4   9950       55  44537   97  1400      3      5
# ...          ...    ...      ...    ...  ...   ...    ...    ...
# 1287        1287   8950       61  81170  110  1600      4      5
# 1288        1288   6750       69  60050  110  1600      3      5
# 1289        1289   7400       75  74096  110  1600      3      5
# 1290        1290  11450       50  50400  110  1600      5      5
# 1291        1291   8500       74  66718  110  1600      3      5
#
#       QuarterlyTax  Weight
# 0               85    1110
# 1               85    1070
# 2               85    1065
# 3               69    1015
# 4               69    1025
# ...

# %% [markdown]
# # Data type conversion

# %%
toyota.info() # check the information of all data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1292 entries, 0 to 1291
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1292 non-null   int64
#  1   Price         1292 non-null   int64
#  2   Age0804       1292 non-null   int64
#  3   KM            1292 non-null   int64
#  4   HP            1292 non-null   int64
#  5   cc            1292 non-null   int64
#  6   Doors         1292 non-null   int64
#  7   Gears         1292 non-null   int64
#  8   QuarterlyTax  1292 non-null   int64
#  9   Weight        1292 non-null   int64
# dtypes: int64(10)
# memory usage: 101.1 KB

# %%
toyota
# Out:
#       Unnamed: 0  Price  Age0804     KM   HP    cc  Doors  Gears  \
# 0              0  16450       20  22588   97  1400      5      5
# 1              1   7950       75  57144  110  1600      5      5
# 2              2  10950       59  79660   86  1300      5      5
# 3              3   8950       65  60000   86  1300      3      5
# 4              4   9950       55  44537   97  1400      3      5
# ...          ...    ...      ...    ...  ...   ...    ...    ...
# 1287        1287   8950       61  81170  110  1600      4      5
# 1288        1288   6750       69  60050  110  1600      3      5
# 1289        1289   7400       75  74096  110  1600      3      5
# 1290        1290  11450       50  50400  110  1600      5      5
# 1291        1291   8500       74  66718  110  1600      3      5
#
#       QuarterlyTax  Weight
# 0               85    1110
# 1               85    1070
# 2               85    1065
# 3               69    1015
# 4               69    1025
# ...

# %%
toyota1=toyota.iloc[:,1:] # here we remove 1st column

# %%
toyota1
# Out:
#       Price  Age0804     KM   HP    cc  Doors  Gears  QuarterlyTax  Weight
# 0     16450       20  22588   97  1400      5      5            85    1110
# 1      7950       75  57144  110  1600      5      5            85    1070
# 2     10950       59  79660   86  1300      5      5            85    1065
# 3      8950       65  60000   86  1300      3      5            69    1015
# 4      9950       55  44537   97  1400      3      5            69    1025
# ...     ...      ...    ...  ...   ...    ...    ...           ...     ...
# 1287   8950       61  81170  110  1600      4      5            69    1040
# 1288   6750       69  60050  110  1600      3      5            69    1050
# 1289   7400       75  74096  110  1600      3      5            69    1050
# 1290  11450       50  50400  110  1600      5      5            85    1080
# 1291   8500       74  66718  110  1600      3      5            69    1050
#
# [1292 rows x 9 columns]

# %%
toyota2=toyota1.copy() # here we use copy() so that any changes made in new DataFrame don't get reflected in the original one

# %%
toyota2
# Out:
#       Price  Age0804     KM   HP    cc  Doors  Gears  QuarterlyTax  Weight
# 0     16450       20  22588   97  1400      5      5            85    1110
# 1      7950       75  57144  110  1600      5      5            85    1070
# 2     10950       59  79660   86  1300      5      5            85    1065
# 3      8950       65  60000   86  1300      3      5            69    1015
# 4      9950       55  44537   97  1400      3      5            69    1025
# ...     ...      ...    ...  ...   ...    ...    ...           ...     ...
# 1287   8950       61  81170  110  1600      4      5            69    1040
# 1288   6750       69  60050  110  1600      3      5            69    1050
# 1289   7400       75  74096  110  1600      3      5            69    1050
# 1290  11450       50  50400  110  1600      5      5            85    1080
# 1291   8500       74  66718  110  1600      3      5            69    1050
#
# [1292 rows x 9 columns]

# %%
toyota2.tail()
# Out:
#       Price  Age0804     KM   HP    cc  Doors  Gears  QuarterlyTax  Weight
# 1287   8950       61  81170  110  1600      4      5            69    1040
# 1288   6750       69  60050  110  1600      3      5            69    1050
# 1289   7400       75  74096  110  1600      3      5            69    1050
# 1290  11450       50  50400  110  1600      5      5            85    1080
# 1291   8500       74  66718  110  1600      3      5            69    1050

# %%
toyota2['Doors']=toyota2['Doors'].astype('category')  # we convert the int into category dtype

# %%
toyota2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1292 entries, 0 to 1291
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Price         1292 non-null   int64
#  1   Age0804       1292 non-null   int64
#  2   KM            1292 non-null   int64
#  3   HP            1292 non-null   int64
#  4   cc            1292 non-null   int64
#  5   Doors         1292 non-null   category
#  6   Gears         1292 non-null   int64
#  7   QuarterlyTax  1292 non-null   int64
#  8   Weight        1292 non-null   int64
# dtypes: category(1), int64(8)
# memory usage: 82.3 KB

# %% [markdown]
# # Duplicates

# %%
toyota2[toyota2.duplicated()].shape # count the duplicates rows
# Out:
# (1, 9)

# %%
toyota2
# Out:
#       Price  Age0804     KM   HP    cc Doors  Gears  QuarterlyTax  Weight
# 0     16450       20  22588   97  1400     5      5            85    1110
# 1      7950       75  57144  110  1600     5      5            85    1070
# 2     10950       59  79660   86  1300     5      5            85    1065
# 3      8950       65  60000   86  1300     3      5            69    1015
# 4      9950       55  44537   97  1400     3      5            69    1025
# ...     ...      ...    ...  ...   ...   ...    ...           ...     ...
# 1287   8950       61  81170  110  1600     4      5            69    1040
# 1288   6750       69  60050  110  1600     3      5            69    1050
# 1289   7400       75  74096  110  1600     3      5            69    1050
# 1290  11450       50  50400  110  1600     5      5            85    1080
# 1291   8500       74  66718  110  1600     3      5            69    1050
#
# [1292 rows x 9 columns]

# %%
toyota2[toyota2.duplicated()]# print the duplicated rows
# Out:
#       Price  Age0804     KM   HP    cc Doors  Gears  QuarterlyTax  Weight
# 1267  24950        8  13253  116  2000     5      5           234    1320

# %%
toyota_1=toyota2.drop_duplicates() # we drop dulpicate rows

# %%
toyota_1.shape
# Out:
# (1291, 9)

# %% [markdown]
# # Drop columns

# %%
toyota_2=toyota_1.drop('Gears',axis=1)

# %%
toyota_2
# Out:
#       Price  Age0804     KM   HP    cc Doors  QuarterlyTax  Weight
# 0     16450       20  22588   97  1400     5            85    1110
# 1      7950       75  57144  110  1600     5            85    1070
# 2     10950       59  79660   86  1300     5            85    1065
# 3      8950       65  60000   86  1300     3            69    1015
# 4      9950       55  44537   97  1400     3            69    1025
# ...     ...      ...    ...  ...   ...   ...           ...     ...
# 1287   8950       61  81170  110  1600     4            69    1040
# 1288   6750       69  60050  110  1600     3            69    1050
# 1289   7400       75  74096  110  1600     3            69    1050
# 1290  11450       50  50400  110  1600     5            85    1080
# 1291   8500       74  66718  110  1600     3            69    1050
#
# [1291 rows x 8 columns]

# %% [markdown]
# # outliers

# %%
# histogram of Ozone
toyota_2['Price'].hist()
# Out:
# <AxesSubplot:>

# %%
#Box plot
toyota_2.boxplot(column=['Price'])
# Out:
# <AxesSubplot:>

# %%
#Descriptive stat
toyota_2['Price'].describe()
# Out:
# count     1291.000000
# mean     10721.456235
# std       3602.167555
# min       4400.000000
# 25%       8450.000000
# 50%       9900.000000
# 75%      11912.500000
# max      31275.000000
# Name: Price, dtype: float64

# %%
#Bar plot
toyota_2['Doors'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Missing Values and Imputation

# %%
import seaborn as sns
cols = toyota_2.columns 
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(toyota_2[cols].isnull(),
            cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Transformations

# %%
#Creating dummy variable for Weather column
toyota_3=pd.get_dummies(toyota2,columns=['Doors'])

# %%
toyota_3
# Out:
#       Price  Age0804     KM   HP    cc  Gears  QuarterlyTax  Weight  Doors_2  \
# 0     16450       20  22588   97  1400      5            85    1110        0
# 1      7950       75  57144  110  1600      5            85    1070        0
# 2     10950       59  79660   86  1300      5            85    1065        0
# 3      8950       65  60000   86  1300      5            69    1015        0
# 4      9950       55  44537   97  1400      5            69    1025        0
# ...     ...      ...    ...  ...   ...    ...           ...     ...      ...
# 1287   8950       61  81170  110  1600      5            69    1040        0
# 1288   6750       69  60050  110  1600      5            69    1050        0
# 1289   7400       75  74096  110  1600      5            69    1050        0
# 1290  11450       50  50400  110  1600      5            85    1080        0
# 1291   8500       74  66718  110  1600      5            69    1050        0
#
#       Doors_3  Doors_4  Doors_5
# ...

# %% [markdown]
# # Normalization of the data

# %%
#Normalization of the data
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

# %%
toyota_3.values
# Out:
# array([[16450,    20, 22588, ...,     0,     0,     1],
#        [ 7950,    75, 57144, ...,     0,     0,     1],
#        [10950,    59, 79660, ...,     0,     0,     1],
#        ...,
#        [ 7400,    75, 74096, ...,     1,     0,     0],
#        [11450,    50, 50400, ...,     0,     0,     1],
#        [ 8500,    74, 66718, ...,     1,     0,     0]], dtype=int64)

# %%
array = toyota_2.values

scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(array[:,0:5])

#transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,:])
# Out:
# [[0.45 0.24 0.09 0.23 0.01]
#  [0.13 0.94 0.24 0.33 0.02]
#  [0.24 0.73 0.33 0.14 0.  ]
#  [0.17 0.81 0.25 0.14 0.  ]
#  [0.21 0.68 0.18 0.23 0.01]]

# %%
# Standardize data (0 mean, 1 stdev)
from sklearn.preprocessing import StandardScaler

# %%
array = toyota_3.values
scaler = StandardScaler().fit(array)
rescaledX = scaler.transform(array)

# summarize transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,:])
# Out:
# [[ 1.58 -1.94 -1.22 -0.29 -0.4  -0.15 -0.06  0.76 -0.03 -0.87 -0.32  1.06]
#  [-0.77  1.03 -0.3   0.56  0.05 -0.15 -0.06 -0.04 -0.03 -0.87 -0.32  1.06]
#  [ 0.06  0.16  0.29 -1.01 -0.62 -0.15 -0.06 -0.14 -0.03 -0.87 -0.32  1.06]
#  [-0.49  0.49 -0.23 -1.01 -0.62 -0.15 -0.45 -1.13 -0.03  1.14 -0.32 -0.94]
#  [-0.22 -0.05 -0.64 -0.29 -0.4  -0.15 -0.45 -0.93 -0.03  1.14 -0.32 -0.94]]

# %% [markdown]
# # Speed up the EDA process

# %%
EDA_report= pp.ProfileReport(toyota)
EDA_report.to_file(output_file='report.html')

# %%
sweet_report = sv.analyze(toyota)
sweet_report.show_html('Doors_report.html')
# Out:
# ...
# Report Doors_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# # Correlation Matrix

# %%
toyota_2.corr()
# Out:
#                  Price   Age0804        KM        HP        cc  QuarterlyTax  \
# Price         1.000000 -0.877495 -0.569082  0.321223  0.129188      0.204942
# Age0804      -0.877495  1.000000  0.506603 -0.162206 -0.100236     -0.194335
# KM           -0.569082  0.506603  1.000000 -0.332778  0.097143      0.295212
# HP            0.321223 -0.162206 -0.332778  1.000000  0.038720     -0.302874
# cc            0.129188 -0.100236  0.097143  0.038720  1.000000      0.297853
# QuarterlyTax  0.204942 -0.194335  0.295212 -0.302874  0.297853      1.000000
# Weight        0.600967 -0.487874 -0.030323  0.104244  0.342046      0.629073
#
#                 Weight
# Price         0.600967
# Age0804      -0.487874
# KM           -0.030323
# HP            0.104244
# cc            0.342046
# QuarterlyTax  0.629073
# Weight        1.000000

# %% [markdown]
# # Scatterplot between variables along with histograms

# %%
#Format the plot background and scatter plots for all the variables
sns.set_style(style='darkgrid')
sns.pairplot(toyota_2)

# %% [markdown]
# # Preparing a model

# %%
#Build model
import statsmodels.formula.api as smf 
model = smf.ols('Price~Age0804+KM+HP+cc+QuarterlyTax+Weight',data=toyota_2).fit()

# %%
#Coefficients
model.params
# Out:
# Intercept      -5622.207546
# Age0804         -119.307334
# KM                -0.020166
# HP                30.454579
# cc                -0.135625
# QuarterlyTax       1.627780
# Weight            19.960904
# dtype: float64

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.867
# Model:                            OLS   Adj. R-squared:                  0.866
# Method:                 Least Squares   F-statistic:                     1396.
# Date:                Thu, 29 Apr 2021   Prob (F-statistic):               0.00
# Time:                        14:24:12   Log-Likelihood:                -11101.
# No. Observations:                1291   AIC:                         2.222e+04
# Df Residuals:                    1284   BIC:                         2.225e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
#t and p-Values
print(model.tvalues, '\n', model.pvalues)
# Out:
# Intercept       -4.790523
# Age0804        -43.230160
# KM             -15.567053
# HP              10.871589
# cc              -1.522841
# QuarterlyTax     1.174060
# Weight          17.152004
# dtype: float64
#  Intercept        1.856995e-06
# Age0804         9.826935e-253
# KM               3.477689e-50
# HP               2.135701e-26
# cc               1.280447e-01
# QuarterlyTax     2.405886e-01
# Weight           1.552888e-59
# dtype: float64

# %%
#R squared values
(model.rsquared,model.rsquared_adj)
# Out:
# (0.8670409554994443, 0.86641965155318)

# %% [markdown]
# # Calculating VIF

# %%
rsq_ag = smf.ols('Age0804~KM+HP+cc+QuarterlyTax+Weight',data=toyota_2).fit().rsquared  
vif_ag = 1/(1-rsq_ag) 

rsq_km = smf.ols('KM~Age0804+HP+cc+QuarterlyTax+Weight',data=toyota_2).fit().rsquared  
vif_km = 1/(1-rsq_km) 

rsq_hp = smf.ols('HP~Age0804+KM+cc+QuarterlyTax+Weight',data=toyota_2).fit().rsquared  
vif_hp = 1/(1-rsq_hp) 

rsq_cc = smf.ols('cc~Age0804+KM+HP+QuarterlyTax+Weight',data=toyota_2).fit().rsquared  
vif_cc = 1/(1-rsq_cc) 

rsq_quarterly = smf.ols('QuarterlyTax~Age0804+KM+HP+cc+Weight',data=toyota_2).fit().rsquared  
vif_quarterly = 1/(1-rsq_quarterly) 

rsq_weight = smf.ols('Weight~Age0804+KM+HP+QuarterlyTax+QuarterlyTax',data=toyota_2).fit().rsquared  
vif_weight = 1/(1-rsq_weight) 

# Storing vif values in a data frame
d1 = {'Variables':['Age0804','KM','HP','cc','QuarterlyTax','Weight'],'VIF':[vif_ag,vif_km,vif_hp,vif_cc,vif_quarterly,vif_weight]}
Vif_frame = pd.DataFrame(d1)  
Vif_frame
# Out:
#       Variables       VIF
# 0       Age0804  1.941843
# 1            KM  1.774933
# 2            HP  1.359668
# 3            cc  1.161829
# 4  QuarterlyTax  2.380395
# 5        Weight  2.425320

# %% [markdown]
# # Residual Analysis

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q') # line = 45 to draw the diagnoal line
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid>10))
# Out:
# [array([   2,    3,    5,    7,    8,   10,   11,   12,   13,   15,   16,
#           17,   20,   21,   25,   27,   28,   32,   35,   37,   38,   39,
#           40,   43,   44,   45,   46,   47,   51,   52,   54,   57,   58,
#           59,   60,   61,   62,   65,   67,   74,   75,   77,   78,   79,
#           80,   87,   88,   91,   92,   93,   94,   97,  100,  101,  102,
#          103,  110,  114,  120,  122,  126,  129,  131,  132,  134,  135,
#          139,  141,  142,  144,  146,  147,  149,  151,  152,  156,  159,
#          160,  161,  165,  167,  168,  169,  170,  171,  172,  175,  176,
#          177,  179,  180,  182,  184,  187,  188,  189,  190,  193,  198,
#          200,  203,  204,  205,  207,  212,  215,  218,  223,  224,  225,
#          228,  231,  232,  233,  234,  237,  238,  239,  240,  241,  242,
#          243,  244,  247,  249,  251,  254,  260,  261,  262,  264,  266,
#          269,  270,  272,  273,  276,  280,  283,  285,  286,  288,  290,
# ...

# %% [markdown]
# # Residual Plot for Homoscedasticity

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %% [markdown]
# # Residual Vs Regressors

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Age0804", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "KM", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "HP", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "cc", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "QuarterlyTax", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Weight", fig=fig)
plt.show()

# %% [markdown]
# # Cook’s Distance

# %%
model_influence = model.get_influence()
(c, _) = model_influence.cooks_distance

# %%
#Plot the influencers values using stem plot
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(toyota_2)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
#index and value of influencer where c is more than .5
(np.argmax(c),np.max(c))
# Out:
# (862, 142.08433148187916)

# %% [markdown]
# # High Influence points

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()

# %%
k = toyota_2.shape[1]
n = toyota_2.shape[0]
leverage_cutoff = 3*((k + 1)/n)

# %%
toyota_2[toyota_2.index.isin([451, 862])]
# Out:
#      Price  Age0804     KM   HP     cc Doors  QuarterlyTax  Weight
# 451   9390       66  50806   86   1300     3            19    1480
# 862  18950       25  20019  110  16000     5           100    1180

# %%
#See the differences in HP and other variable values
toyota_2.head()
# Out:
#    Price  Age0804     KM   HP    cc Doors  QuarterlyTax  Weight
# 0  16450       20  22588   97  1400     5            85    1110
# 1   7950       75  57144  110  1600     5            85    1070
# 2  10950       59  79660   86  1300     5            85    1065
# 3   8950       65  60000   86  1300     3            69    1015
# 4   9950       55  44537   97  1400     3            69    1025

# %% [markdown]
# # Improving the model

# %%
#Load the data
toyota_new = pd.read_excel("E:\\Desktop\kaggle.xlsx")

# %%
#Discard the data points which are influencers and reasign the row number (reset_index())
toyota1=toyota_new.drop(toyota_new.index[[451,862]],axis=0).reset_index()

# %%
#Drop the original index
toyota1=toyota1.drop(['index'],axis=1)

# %%
toyota1
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     16450         20  22588   97  1400      5      5             85    1110
# 1      7950         75  57144  110  1600      5      5             85    1070
# 2     10950         59  79660   86  1300      5      5             85    1065
# 3      8950         65  60000   86  1300      3      5             69    1015
# 4      9950         55  44537   97  1400      3      5             69    1025
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1285   8950         61  81170  110  1600      4      5             69    1040
# 1286   6750         69  60050  110  1600      3      5             69    1050
# 1287   7400         75  74096  110  1600      3      5             69    1050
# 1288  11450         50  50400  110  1600      5      5             85    1080
# 1289   8500         74  66718  110  1600      3      5             69    1050
#
# [1290 rows x 9 columns]

# %% [markdown]
# # Build Model

# %%
#Exclude variable "HP" and generate R-Squared and AIC values
final_ml_V= smf.ols('Price~Age_08_04+KM+cc+Quarterly_Tax+Weight',data = toyota1).fit()

# %%
(final_ml_V.rsquared,final_ml_V.aic)
# Out:
# (0.8690485681693263, 22188.95817835514)

# %%
#Exclude variable "weight" and generate R-Squared and AIC values
final_ml_W= smf.ols('Price~Age_08_04+HP+KM+cc+Quarterly_Tax',data = toyota1).fit()

# %%
(final_ml_W.rsquared,final_ml_W.aic)
# Out:
# (0.8374800975623824, 22467.564594155745)

# %% [markdown]
# # Cook’s Distance

# %%
model_influence_V = final_ml_V.get_influence()
(c_V, _) = model_influence_V.cooks_distance

# %%
fig= plt.subplots(figsize=(20,7))
plt.stem(np.arange(len(toyota1)),np.round(c_V,3));
plt.xlabel('Row index')
plt.ylabel('Cooks Distance');

# %%
#index of the data points where c is more than .5
(np.argmax(c_V),np.max(c_V))
# Out:
# (571, 0.4137002477553416)

# %%
#Drop 76 and 77 observations
toyota2=toyota1.drop(toyota1.index[[300,590]],axis=0)

# %%
toyota2
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     16450         20  22588   97  1400      5      5             85    1110
# 1      7950         75  57144  110  1600      5      5             85    1070
# 2     10950         59  79660   86  1300      5      5             85    1065
# 3      8950         65  60000   86  1300      3      5             69    1015
# 4      9950         55  44537   97  1400      3      5             69    1025
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1285   8950         61  81170  110  1600      4      5             69    1040
# 1286   6750         69  60050  110  1600      3      5             69    1050
# 1287   7400         75  74096  110  1600      3      5             69    1050
# 1288  11450         50  50400  110  1600      5      5             85    1080
# 1289   8500         74  66718  110  1600      3      5             69    1050
#
# [1288 rows x 9 columns]

# %%
#Reset the index and re arrange the row values
toyota3=toyota2.reset_index()

# %%
toyota4=toyota3.drop(['index'],axis=1)

# %%
#Build the model on the new data
final_ml_V= smf.ols('Price~Age_08_04+HP+KM+cc+Quarterly_Tax',data = toyota4).fit()

# %%
#Again check for influencers
model_influence_V = final_ml_V.get_influence()
(c_V, _) = model_influence_V.cooks_distance

# %%
fig= plt.subplots(figsize=(20,7))
plt.stem(np.arange(len(toyota4)),np.round(c_V,3));
plt.xlabel('Row index')
plt.ylabel('Cooks Distance');

# %%
#index of the data points where c is more than .5
(np.argmax(c_V),np.max(c_V))
# Out:
# (1252, 0.1715460533078588)

# %%
#Check the accuracy of the mode
final_ml_V= smf.ols('Price~Age_08_04+HP+KM+cc+Quarterly_Tax',data = toyota4).fit()

# %%
(final_ml_V.rsquared,final_ml_V.aic)
# Out:
# (0.8374003648391046, 22434.56688147298)

# %% [markdown]
# # Predicting for new data

# %%
final_ml_V.predict(toyota_new.iloc[0:5,])
# Out:
# 0    16354.133780
# 1     8681.338465
# 2     9394.199707
# 3     8656.498377
# 4    10828.548120
# dtype: float64

# %%
pred_y = final_ml_V.predict(toyota_new)

# %%
pred_y
# Out:
# 0       16354.133780
# 1        8681.338465
# 2        9394.199707
# 3        8656.498377
# 4       10828.548120
#             ...
# 1287     9879.445798
# 1288     9173.931667
# 1289     8080.709015
# 1290    12259.085872
# 1291     8357.984279
# Length: 1292, dtype: float64

# %%
np.sqrt(np.mean((toyota_new.Price-pred_y)**2)) #RMSE value
# Out:
# 1467.007213875235
